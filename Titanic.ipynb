# %%
import pandas as pd

tnc = pd.read_csv(r'C:\Users\admin\Titanic\TitanicDataset.csv')

tnc.sort_values(by = "age" , ascending = False)
# Out:
#                            Unnamed: 0 survived male_famale   age  \
# 14    Barkworth, Mr. Algernon Henry W      yes        male  80.0
# 61     Cavendish, Mrs. Tyrell William      yes      female  76.0
# 1235              Svensson, Mr. Johan       no        male  74.0
# 135         Goldschmidt, Mr. George B       no        male  71.0
# 9             Artagaveytia, Mr. Ramon       no        male  71.0
# ...                               ...      ...         ...   ...
# 1293   Williams, Mr. Howard Hugh Harr       no        male   NaN
# 1297           Wiseman, Mr. Phillippe       no        male   NaN
# 1302                Yousif, Mr. Wazli       no        male   NaN
# 1303            Yousseff, Mr. Gerious       no        male   NaN
# 1305            Zabour, Miss. Thamine       no      female   NaN
#
#      passengerClass
# 14              1st
# 61              1st
# 1235            3rd
# 135             1st
# 9               1st
# ...             ...
# 1293            3rd
# ...

# %%
male = pd.DataFrame(tnc)
male = male.loc[tnc["male_famale"] == 'male']
male
# Out:
#                            Unnamed: 0 survived male_famale      age  \
# 1      Allison, Master. Hudson Trevor      yes        male   0.9167
# 3     Allison, Mr. Hudson Joshua Crei       no        male  30.0000
# 5                 Anderson, Mr. Harry      yes        male  48.0000
# 7              Andrews, Mr. Thomas Jr       no        male  39.0000
# 9             Artagaveytia, Mr. Ramon       no        male  71.0000
# ...                               ...      ...         ...      ...
# 1302                Yousif, Mr. Wazli       no        male      NaN
# 1303            Yousseff, Mr. Gerious       no        male      NaN
# 1306        Zakarian, Mr. Mapriededer       no        male  26.5000
# 1307              Zakarian, Mr. Ortin       no        male  27.0000
# 1308               Zimmerman, Mr. Leo       no        male  29.0000
#
#      passengerClass
# 1               1st
# 3               1st
# 5               1st
# 7               1st
# 9               1st
# ...             ...
# ...

# %%
female = pd.DataFrame(tnc)
female = female.loc[tnc["male_famale"] == 'female']
female
# Out:
#                            Unnamed: 0 survived male_famale   age  \
# 0       Allen, Miss. Elisabeth Walton      yes      female  29.0
# 2        Allison, Miss. Helen Loraine       no      female   2.0
# 4     Allison, Mrs. Hudson J C (Bessi       no      female  25.0
# 6     Andrews, Miss. Kornelia Theodos      yes      female  63.0
# 8     Appleton, Mrs. Edward Dale (Cha      yes      female  53.0
# ...                               ...      ...         ...   ...
# 1286  Whabee, Mrs. George Joseph (Sha      yes      female  38.0
# 1290  Wilkes, Mrs. James (Ellen Needs      yes      female  47.0
# 1300  Yasbeck, Mrs. Antoni (Selini Al      yes      female  15.0
# 1304             Zabour, Miss. Hileni       no      female  14.5
# 1305            Zabour, Miss. Thamine       no      female   NaN
#
#      passengerClass
# 0               1st
# 2               1st
# 4               1st
# 6               1st
# 8               1st
# ...             ...
# 1286            3rd
# ...

# %%
msrv = pd.DataFrame(male)
msrv = msrv[msrv["survived"] == 'yes']
msrv.sort_values(by = "age" , ascending = False)
# Out:
#                            Unnamed: 0 survived male_famale   age  \
# 14    Barkworth, Mr. Algernon Henry W      yes        male  80.0
# 432                Harris, Mr. George      yes        male  62.0
# 123   Frolicher-Stehli, Mr. Maxmillia      yes        male  60.0
# 264   Simonius-Blumer, Col. Oberst Al      yes        male  56.0
# 280   Stengel, Mr. Charles Emil Henry      yes        male  54.0
# ...                               ...      ...         ...   ...
# 1034         Moubarek, Master. Gerios      yes        male   NaN
# 1035   Moubarek, Master. Halim Gonios      yes        male   NaN
# 1080             O'Keefe, Mr. Patrick      yes        male   NaN
# 1121         Peter, Master. Michael J      yes        male   NaN
# 1162                 Ryan, Mr. Edward      yes        male   NaN
#
#      passengerClass
# 14              1st
# 432             2nd
# 123             1st
# 264             1st
# 280             1st
# ...             ...
# 1034            3rd
# ...

# %%
munsrv = pd.DataFrame(male)
munsrv = munsrv[munsrv["survived"] == 'no']
munsrv.sort_values(by = "age" , ascending = False)
# Out:
#                           Unnamed: 0 survived male_famale   age passengerClass
# 1235             Svensson, Mr. Johan       no        male  74.0            3rd
# 135        Goldschmidt, Mr. George B       no        male  71.0            1st
# 9            Artagaveytia, Mr. Ramon       no        male  71.0            1st
# 727             Connors, Mr. Patrick       no        male  70.5            3rd
# 506      Mitchell, Mr. Henry Michael       no        male  70.0            2nd
# ...                              ...      ...         ...   ...            ...
# 1292              Willey, Mr. Edward       no        male   NaN            3rd
# 1293  Williams, Mr. Howard Hugh Harr       no        male   NaN            3rd
# 1297          Wiseman, Mr. Phillippe       no        male   NaN            3rd
# 1302               Yousif, Mr. Wazli       no        male   NaN            3rd
# 1303           Yousseff, Mr. Gerious       no        male   NaN            3rd
#
# [682 rows x 5 columns]

# %%
fsrv = pd.DataFrame(female)
fsrv = fsrv[fsrv["survived"] == 'yes']
fsrv.sort_values(by = "age" , ascending = False)
# Out:
#                            Unnamed: 0 survived male_famale   age  \
# 61     Cavendish, Mrs. Tyrell William      yes      female  76.0
# 83    Crosby, Mrs. Edward Gifford (Ca      yes      female  64.0
# 78     Compton, Mrs. Alexander Taylor      yes      female  64.0
# 1261           Turkula, Mrs. (Hedwig)      yes      female  63.0
# 6     Andrews, Miss. Kornelia Theodos      yes      female  63.0
# ...                               ...      ...         ...   ...
# 1149    Riordan, Miss. Johanna Hannah      yes      female   NaN
# 1159              Roth, Miss. Sarah A      yes      female   NaN
# 1198       Shine, Miss. Ellen Natalia      yes      female   NaN
# 1216               Smyth, Miss. Julia      yes      female   NaN
# 1247  Thorneycroft, Mrs. Percival (Fl      yes      female   NaN
#
#      passengerClass
# 61              1st
# 83              1st
# 78              1st
# 1261            3rd
# 6               1st
# ...             ...
# 1149            3rd
# ...

# %%
funsrv = pd.DataFrame(female)
funsrv = funsrv[funsrv["survived"] == 'no']
funsrv.sort_values(by = "age" , ascending = False)
# Out:
#                            Unnamed: 0 survived male_famale   age  \
# 286   Straus, Mrs. Isidor (Rosalie Id       no      female  63.0
# 456   Howard, Mrs. Benjamin (Ellen Tr       no      female  60.0
# 490                 Mack, Mrs. (Mary)       no      female  57.0
# 169        Isham, Miss. Ann Elizabeth       no      female  50.0
# 811   Ford, Mrs. Edward (Margaret Ann       no      female  48.0
# ...                               ...      ...         ...   ...
# 1173     Sage, Miss. Constance Gladys       no      female   NaN
# 1174   Sage, Miss. Dorothy Edith Doll       no      female   NaN
# 1175          Sage, Miss. Stella Anna       no      female   NaN
# 1180   Sage, Mrs. John (Annie Bullen)       no      female   NaN
# 1305            Zabour, Miss. Thamine       no      female   NaN
#
#      passengerClass
# 286             1st
# 456             2nd
# 490             2nd
# 169             1st
# 811             3rd
# ...             ...
# 1173            3rd
# ...
